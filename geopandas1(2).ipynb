# %%
pip install geopandas

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# %%
#Caminho do shapefile (.shp)
shapefile_path = '/home/ifmt-aluno/Downloads/Municipio/MT_Municipios_2025/MT_Municipios_2025.shp'

#Coordenadas do ponto
latitude = -15.867995956787732
longitude = -52.2729580863824

# %%
#LEITURA DO SHAPEFILE
gdf = gpd.read_file(shapefile_path)

#Verifica e ajusta o CRS, se necessário
if gdf.crs is None:
    raise ValueError("O shapefile não possui CRS definido.")

#Cria o ponto em WGS84 (EPSG:4326)
ponto = gpd.GeoDataFrame(
    {"nome":["Ponro de interesse"]},
    geometry=[Point(longitude, latitude)],
    crs="EPSG:4326")

#Reprojeta o ponto para o mesmo CRS do shapefile, se necessário
if gdf.crs != ponto.crs:
    ponto = ponto.to_crs(gdf.crs)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plota o shapefile
gdf.plot(ax=ax, edgecolor="black", alpha=0.6)

# Plota o ponto
ponto.plot(ax=ax, marker="o", markersize=80, color="red", label="Ponto")

# Adiciona rótulo ao ponto
x = ponto.geometry.iloc[0].x
y = ponto.geometry.iloc[0].y
ax.text(x, y, "Ponto de Interesse", fontsize=10, verticalalignment="bottom")

# Título e Legenda
ax.set_title("Mapa com ponto marcado", fontsize=14)
ax.legend()
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

plt.show()

# %%
gdf
# Out:
#       CD_MUN                 NM_MUN  CD_RGI  \
# 0    5103700            Feliz Natal  510007
# 1    5103809  Figueirópolis D'Oeste  510006
# 2    5104104      Guarantã do Norte  510011
# 3    5103957         Glória D'Oeste  510006
# 4    5103361      Conquista D'Oeste  510005
# ..       ...                    ...     ...
# 137  5104559                 Itaúba  510007
# 138  5104542              Itanhangá  510008
# 139  5104526      Ipiranga do Norte  510008
# 140  5103858        Gaúcha do Norte  510015
# 141  5103908       General Carneiro  510013
#
#                                      NM_RGI CD_RGINT         NM_RGINT CD_UF  \
# 0                                     Sinop     5103            Sinop    51
# 1                          Mirassol D'oeste     5102          Cáceres    51
# 2    Peixoto de Azevedo - Guarantã do Norte     5103            Sinop    51
# 3                          Mirassol D'oeste     5102          Cáceres    51
# 4               Pontes e Lacerda - Comodoro     5102          Cáceres    51
# ..                                      ...      ...              ...   ...
# 137                                   Sinop     5103            Sinop    51
# 138                                 Sorriso     5103            Sinop    51
# 139                                 Sorriso     5103            Sinop    51
# 140                                Água Boa     5104  Barra do Garças    51
# 141                         Barra do Garças     5104  Barra do Garças    51
#
#            NM_UF SIGLA_UF CD_REGIAO     NM_REGIAO SIGLA_RG CD_CONCURB  \
# 0    Mato Grosso       MT         5  Centro-oeste       CO       None
# 1    Mato Grosso       MT         5  Centro-oeste       CO       None
# 2    Mato Grosso       MT         5  Centro-oeste       CO       None
# 3    Mato Grosso       MT         5  Centro-oeste       CO       None
# 4    Mato Grosso       MT         5  Centro-oeste       CO       None
# ..           ...      ...       ...           ...      ...        ...
# 137  Mato Grosso       MT         5  Centro-oeste       CO       None
# 138  Mato Grosso       MT         5  Centro-oeste       CO       None
# 139  Mato Grosso       MT         5  Centro-oeste       CO       None
# 140  Mato Grosso       MT         5  Centro-oeste       CO       None
# 141  Mato Grosso       MT         5  Centro-oeste       CO       None
#
#     NM_CONCURB   AREA_KM2                                           geometry
# 0         None  11661.514  POLYGON ((-55.27805 -12.66227, -55.27801 -12.6...
# 1         None    891.448  POLYGON ((-58.59943 -15.48359, -58.59939 -15.4...
# 2         None   4725.273  POLYGON ((-54.89067 -10.05088, -54.90878 -10.0...
# 3         None    833.131  POLYGON ((-58.17217 -15.93546, -58.1712 -15.93...
# 4         None   2684.676  POLYGON ((-59.15576 -14.68583, -59.15584 -14.6...
# ..         ...        ...                                                ...
# 137       None   4521.790  POLYGON ((-55.44054 -11.21365, -55.44133 -11.2...
# 138       None   2909.745  POLYGON ((-56.93141 -12.29694, -56.93055 -12.2...
# 139       None   3422.016  POLYGON ((-55.90644 -12.19491, -55.90683 -12.1...
# 140       None  16908.375  POLYGON ((-53.417 -13.66792, -53.41677 -13.666...
# 141       None   4514.917  POLYGON ((-53.938 -15.62128, -53.9379 -15.6210...
#
# [142 rows x 16 columns]

# %%
gdf_BAG= gdf[gdf['NM_MUN']=='Barra do Garças']

# %%
gdf_BAG.plot()
# Out:
# <Axes: >

# %%
ig, ax = plt.subplots(figsize=(10, 10))

# Plota o shapefile
gdf_BAG.plot(ax=ax, edgecolor="black", alpha=0.6)

# Plota o ponto
ponto.plot(ax=ax, marker="o", markersize=80, color="red", label="Ponto")

# Adiciona rótulo ao ponto
x = ponto.geometry.iloc[0].x
y = ponto.geometry.iloc[0].y
ax.text(x, y, "Ponto de Interesse", fontsize=10, verticalalignment="bottom")

# Título e Legenda
ax.set_title("Mapa com ponto marcado", fontsize=14)
ax.legend()
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")

plt.show()
